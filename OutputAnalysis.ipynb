# %% [markdown]
# # Initial Analaysis of outputs

# %%
from date_parser import to_date
import os
import json
import pandas as pd
from collections import defaultdict
import ast
from tqdm import tqdm
import numpy as np
from datetime import datetime, timedelta, timezone


solution_path = "fctryengine_outputs/schedule.json"
datapath = 'fctryengine_outputs/data/'


def load_json_from_path(path):
    with open(path,'r') as file:
        return json.load(file)


def convert_minutes(minutes):
    days = minutes // (24 * 60)  # Total days
    hours = (minutes % (24 * 60)) // 60  # Remaining hours
    minutes = minutes % 60  # Remaining minutes

    return days, hours, minutes



def convert_string_to_list(input_string):
    # Extracting the inner list representation from the string
    inner_list_str = input_string.strip('dict_values()')
    
    # Safely evaluating the string as a Python literal
    inner_list = ast.literal_eval(inner_list_str)

    # Flatten the list of lists if needed and return
    return [item for sublist in inner_list for item in sublist][0]


def union_of_lists(list_of_lists):
    result = []
    for sublist in list_of_lists:
        result +=sublist
    return set(result)


def minutes_since(date_str, reference_date_str = '2023-11-27 00:00:00'):
    """
    Calculates how many minutes have passed since a reference date.

    Parameters:
    date_str (str): A date in the format 'YYYY-MM-DD HH:MM:SS+00:00'.
    reference_date_str (str): A reference date in the format 'DD-MM-YYYY'.

    Returns:
    int: Number of minutes that have passed since the reference date.
    """

    date_str = date_str.split('+')[0]

    # Convert the date strings to datetime objects
    date = datetime.strptime(date_str, '%Y-%m-%d %H:%M:%S')
    reference_date = datetime.strptime(reference_date_str, '%Y-%m-%d %H:%M:%S')
    

    # Calculate the difference in minutes
    difference = date - reference_date
    return int(difference.total_seconds() // 60)


def add_minutes_to_date(minutes, reference_date_str = '2023-11-27 00:00:00'):
    """
    Adds a certain number of minutes to a reference date.

    Parameters:
    minutes (int): The number of minutes to add.
    reference_date_str (str): A reference date in the format 'YYYY-MM-DD HH:MM:SS'.

    Returns:
    datetime: The new date and time.
    """
    # Convert the reference date string to a datetime object
    reference_date = datetime.strptime(reference_date_str, '%Y-%m-%d %H:%M:%S')

    # Add the minutes to the reference date
    new_date = reference_date + timedelta(minutes=minutes)

    return new_date


def convert_date_to_datetime(date_str):
    """
    Converts a date string in the format 'YYYY-MM-DD' to a datetime object with time set to 00:00:00.

    Parameters:
    date_str (str): A date in the format 'YYYY-MM-DD'.

    Returns:
    datetime: The datetime object.
    """
    date_str = date_str + " 00:00:00"
    date = datetime.strptime(date_str, '%Y-%m-%d %H:%M:%S')
    return date




all_data_files = {f.split('.')[0]:load_json_from_path(datapath+f) for f in  os.listdir(datapath)}
solution = load_json_from_path(solution_path)

# %%
# PLAN
all_data_files['tasks']
# Out:
# [{'taskno': 'WO20946-10',
#   'task_id': 79828,
#   'priority': 323,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO29559-10',
#   'task_id': 102804,
#   'priority': 328,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO30798-20',
#   'task_id': 106244,
#   'priority': 324,
#   'duration': 120,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [3],
#   'resource_count': 1,
#   'rule_id': 8},
#  {'taskno': 'WO30819-20',
#   'task_id': 106255,
#   'priority': 339,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [3],
#   'resource_count': 1,
#   'rule_id': 8},
#  {'taskno': 'WO30820-20',
#   'task_id': 106257,
#   'priority': 325,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [3],
#   'resource_count': 1,
#   'rule_id': 8},
#  {'taskno': 'WO33143-20',
#   'task_id': 113294,
#   'priority': 326,
#   'duration': 200,
#   'quantity': 10.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [3],
#   'resource_count': 1,
#   'rule_id': 8},
#  {'taskno': 'WO49921-20',
#   'task_id': 159572,
#   'priority': 327,
#   'duration': 40,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [3],
#   'resource_count': 1,
#   'rule_id': 8},
#  {'taskno': 'WO55598-10',
#   'task_id': 177178,
#   'priority': 334,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [40],
#   'resource_count': 1,
#   'rule_id': 22},
#  {'taskno': 'WO57986-10',
#   'task_id': 184855,
#   'priority': 329,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO59712-40',
#   'task_id': 192604,
#   'priority': 330,
#   'duration': 150,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [39],
#   'resource_count': 1,
#   'rule_id': 18},
#  {'taskno': 'WO65565-10',
#   'task_id': 216047,
#   'priority': 331,
#   'duration': 39,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO70605-30',
#   'task_id': 235816,
#   'priority': 340,
#   'duration': 900,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO80910-20',
#   'task_id': 267003,
#   'priority': 134,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 8,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [24],
#   'resource_count': 1,
#   'rule_id': 15},
#  {'taskno': 'WO80911-20',
#   'task_id': 267005,
#   'priority': 333,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO80912-20',
#   'task_id': 267007,
#   'priority': 332,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO84929-10',
#   'task_id': 277035,
#   'priority': 335,
#   'duration': 3135,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [77],
#   'resource_count': 1,
#   'rule_id': 39},
#  {'taskno': 'WO84984-10',
#   'task_id': 277205,
#   'priority': 337,
#   'duration': 30,
#   'quantity': 8.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [2, 1],
#   'resource_count': 1,
#   'rule_id': 25},
#  {'taskno': 'WO84985-10',
#   'task_id': 277206,
#   'priority': 336,
#   'duration': 30,
#   'quantity': 8.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [2, 1],
#   'resource_count': 1,
#   'rule_id': 25},
#  {'taskno': 'WO86296-10',
#   'task_id': 281296,
#   'priority': 113,
#   'duration': 30,
#   'quantity': 3.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [2, 1],
#   'resource_count': 1,
#   'rule_id': 25},
#  {'taskno': 'WO86296-20',
#   'task_id': 281297,
#   'priority': 113,
#   'duration': 213,
#   'quantity': 3.0,
#   'predecessors': ['WO86296-10'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO87687-20',
#   'task_id': 284404,
#   'priority': 34,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 8,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [83],
#   'resource_count': 1,
#   'rule_id': 16},
#  {'taskno': 'WO87687-30',
#   'task_id': 284405,
#   'priority': 34,
#   'duration': 735,
#   'quantity': 2.0,
#   'predecessors': ['WO87687-20'],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [2, 1],
#   'resource_count': 1,
#   'rule_id': 25},
#  {'taskno': 'WO87687-40',
#   'task_id': 284406,
#   'priority': 34,
#   'duration': 843,
#   'quantity': 2.0,
#   'predecessors': ['WO87687-30'],
#   'total_resource': 8,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [83],
#   'resource_count': 1,
#   'rule_id': 16},
#  {'taskno': 'WO90646-20',
#   'task_id': 291780,
#   'priority': 338,
#   'duration': 300,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO92235-10',
#   'task_id': 296172,
#   'priority': 39,
#   'duration': 729,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO93770-20',
#   'task_id': 300644,
#   'priority': 84,
#   'duration': 100,
#   'quantity': 5.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [39],
#   'resource_count': 1,
#   'rule_id': 18},
#  {'taskno': 'WO97640-10',
#   'task_id': 309692,
#   'priority': 66,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO99668-10',
#   'task_id': 314310,
#   'priority': 35,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO99668-20',
#   'task_id': 314311,
#   'priority': 35,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': ['WO99668-10'],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO100090-40',
#   'task_id': 315541,
#   'priority': 43,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [39],
#   'resource_count': 1,
#   'rule_id': 18},
#  {'taskno': 'WO100092-30',
#   'task_id': 315551,
#   'priority': 44,
#   'duration': 281,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO100092-40',
#   'task_id': 315552,
#   'priority': 44,
#   'duration': 464,
#   'quantity': 1.0,
#   'predecessors': ['WO100092-30'],
#   'total_resource': 8,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [24],
#   'resource_count': 1,
#   'rule_id': 15},
#  {'taskno': 'WO100312-10',
#   'task_id': 316178,
#   'priority': 67,
#   'duration': 1387,
#   'quantity': 3.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [2, 1],
#   'resource_count': 1,
#   'rule_id': 25},
#  {'taskno': 'WO100312-20',
#   'task_id': 316179,
#   'priority': 67,
#   'duration': 2062,
#   'quantity': 3.0,
#   'predecessors': ['WO100312-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO100312-30',
#   'task_id': 316180,
#   'priority': 67,
#   'duration': 540,
#   'quantity': 3.0,
#   'predecessors': ['WO100312-20'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO100324-10',
#   'task_id': 316194,
#   'priority': 38,
#   'duration': 89,
#   'quantity': 8.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO100801-20',
#   'task_id': 319269,
#   'priority': 82,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [39],
#   'resource_count': 1,
#   'rule_id': 18},
#  {'taskno': 'WO100946-20',
#   'task_id': 320187,
#   'priority': 45,
#   'duration': 30,
#   'quantity': 4.0,
#   'predecessors': [],
#   'total_resource': 3,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [104],
#   'resource_count': 1,
#   'rule_id': 27},
#  {'taskno': 'WO101246-10',
#   'task_id': 320874,
#   'priority': 51,
#   'duration': 30,
#   'quantity': 5.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [2, 1],
#   'resource_count': 1,
#   'rule_id': 25},
#  {'taskno': 'WO101246-20',
#   'task_id': 320875,
#   'priority': 51,
#   'duration': 2220,
#   'quantity': 5.0,
#   'predecessors': ['WO101246-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [77],
#   'resource_count': 1,
#   'rule_id': 39},
#  {'taskno': 'WO101246-30',
#   'task_id': 320876,
#   'priority': 51,
#   'duration': 4720,
#   'quantity': 5.0,
#   'predecessors': ['WO101246-20'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO101262-10',
#   'task_id': 321003,
#   'priority': 138,
#   'duration': 1938,
#   'quantity': 3.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [2, 1],
#   'resource_count': 1,
#   'rule_id': 25},
#  {'taskno': 'WO101262-20',
#   'task_id': 321004,
#   'priority': 138,
#   'duration': 1339,
#   'quantity': 3.0,
#   'predecessors': ['WO101262-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [77],
#   'resource_count': 1,
#   'rule_id': 39},
#  {'taskno': 'WO101262-30',
#   'task_id': 321005,
#   'priority': 138,
#   'duration': 1649,
#   'quantity': 3.0,
#   'predecessors': ['WO101262-20'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO101503-10',
#   'task_id': 321416,
#   'priority': 36,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO101505-10',
#   'task_id': 321418,
#   'priority': 37,
#   'duration': 56,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO101554-20',
#   'task_id': 321493,
#   'priority': 229,
#   'duration': 1726,
#   'quantity': 3.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO101554-30',
#   'task_id': 321494,
#   'priority': 229,
#   'duration': 540,
#   'quantity': 3.0,
#   'predecessors': ['WO101554-20'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO101839-10',
#   'task_id': 322678,
#   'priority': 41,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [36],
#   'resource_count': 1,
#   'rule_id': 20},
#  {'taskno': 'WO102028-10',
#   'task_id': 323722,
#   'priority': 32,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO102029-10',
#   'task_id': 323723,
#   'priority': 292,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO102847-20',
#   'task_id': 326062,
#   'priority': 47,
#   'duration': 30,
#   'quantity': 4.0,
#   'predecessors': [],
#   'total_resource': 3,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [104],
#   'resource_count': 1,
#   'rule_id': 27},
#  {'taskno': 'WO103020-10',
#   'task_id': 326691,
#   'priority': 291,
#   'duration': 3731,
#   'quantity': 3.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [2, 1],
#   'resource_count': 1,
#   'rule_id': 25},
#  {'taskno': 'WO103020-20',
#   'task_id': 326692,
#   'priority': 291,
#   'duration': 2751,
#   'quantity': 3.0,
#   'predecessors': ['WO103020-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO103020-30',
#   'task_id': 326693,
#   'priority': 291,
#   'duration': 540,
#   'quantity': 3.0,
#   'predecessors': ['WO103020-20'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO103451-10',
#   'task_id': 329427,
#   'priority': 64,
#   'duration': 30,
#   'quantity': 4.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO103648-10',
#   'task_id': 331484,
#   'priority': 142,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115275-10'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': True,
#   'resource_group_id': [105, 97],
#   'resource_count': 0,
#   'rule_id': 29},
#  {'taskno': 'WO103649-10',
#   'task_id': 331485,
#   'priority': 141,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': True,
#   'resource_group_id': [105, 97],
#   'resource_count': 0,
#   'rule_id': 29},
#  {'taskno': 'WO103935-10',
#   'task_id': 332508,
#   'priority': 53,
#   'duration': 54,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO103935-20',
#   'task_id': 332509,
#   'priority': 53,
#   'duration': 565,
#   'quantity': 1.0,
#   'predecessors': ['WO103935-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO103940-10',
#   'task_id': 332518,
#   'priority': 52,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO103940-20',
#   'task_id': 332519,
#   'priority': 52,
#   'duration': 690,
#   'quantity': 1.0,
#   'predecessors': ['WO103940-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO103999-10',
#   'task_id': 332805,
#   'priority': 42,
#   'duration': 350,
#   'quantity': 10.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO104119-10',
#   'task_id': 333290,
#   'priority': 173,
#   'duration': 5475,
#   'quantity': 1.0,
#   'predecessors': ['WO115273-10', 'WO104121-20', 'WO104571-10'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': True,
#   'resource_group_id': [105, 97],
#   'resource_count': 0,
#   'rule_id': 29},
#  {'taskno': 'WO104120-10',
#   'task_id': 333293,
#   'priority': 175,
#   'duration': 10106,
#   'quantity': 1.0,
#   'predecessors': ['WO104436-10',
#    'WO104442-10',
#    'WO104437-10',
#    'WO104440-10',
#    'WO104570-10',
#    'WO115274-10',
#    'WO104441-10'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': True,
#   'resource_group_id': [105, 97],
#   'resource_count': 0,
#   'rule_id': 29},
#  {'taskno': 'WO104121-10',
#   'task_id': 333294,
#   'priority': 173,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO104125-10', 'WO104138-10'],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': True,
#   'resource_group_id': [74, 106, 108],
#   'resource_count': 0,
#   'rule_id': 69},
#  {'taskno': 'WO104121-20',
#   'task_id': 333295,
#   'priority': 173,
#   'duration': 180,
#   'quantity': 1.0,
#   'predecessors': ['WO104121-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO104125-10',
#   'task_id': 333400,
#   'priority': 173,
#   'duration': 398,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 10,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [27],
#   'resource_count': 1,
#   'rule_id': 64},
#  {'taskno': 'WO104138-10',
#   'task_id': 333419,
#   'priority': 173,
#   'duration': 349,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 10,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [27],
#   'resource_count': 1,
#   'rule_id': 64},
#  {'taskno': 'WO104436-10',
#   'task_id': 333990,
#   'priority': 175,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO104437-10',
#   'task_id': 333991,
#   'priority': 175,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO104440-10',
#   'task_id': 333994,
#   'priority': 175,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO104441-10',
#   'task_id': 333995,
#   'priority': 175,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO104442-10',
#   'task_id': 333996,
#   'priority': 175,
#   'duration': 50,
#   'quantity': 5.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO104570-10',
#   'task_id': 334193,
#   'priority': 175,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO104571-10',
#   'task_id': 334194,
#   'priority': 173,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO105926-10',
#   'task_id': 339017,
#   'priority': 40,
#   'duration': 30,
#   'quantity': 4.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [44],
#   'resource_count': 1,
#   'rule_id': 55},
#  {'taskno': 'WO106719-10',
#   'task_id': 343201,
#   'priority': 206,
#   'duration': 1231,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 8,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [24],
#   'resource_count': 1,
#   'rule_id': 15},
#  {'taskno': 'WO106719-20',
#   'task_id': 343202,
#   'priority': 206,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO106719-10'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO106726-20',
#   'task_id': 343317,
#   'priority': 63,
#   'duration': 592,
#   'quantity': 4.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO106726-30',
#   'task_id': 343318,
#   'priority': 63,
#   'duration': 444,
#   'quantity': 4.0,
#   'predecessors': ['WO106726-20'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [44],
#   'resource_count': 1,
#   'rule_id': 55},
#  {'taskno': 'WO106735-10',
#   'task_id': 343343,
#   'priority': 56,
#   'duration': 1347,
#   'quantity': 4.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO106735-20',
#   'task_id': 343344,
#   'priority': 56,
#   'duration': 3726,
#   'quantity': 4.0,
#   'predecessors': ['WO106735-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO106735-30',
#   'task_id': 343345,
#   'priority': 56,
#   'duration': 268,
#   'quantity': 4.0,
#   'predecessors': ['WO106735-20'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [31],
#   'resource_count': 1,
#   'rule_id': 54},
#  {'taskno': 'WO106735-40',
#   'task_id': 343346,
#   'priority': 56,
#   'duration': 40,
#   'quantity': 4.0,
#   'predecessors': ['WO106735-30'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [42],
#   'resource_count': 1,
#   'rule_id': 21},
#  {'taskno': 'WO106735-50',
#   'task_id': 343347,
#   'priority': 56,
#   'duration': 40,
#   'quantity': 4.0,
#   'predecessors': ['WO106735-40'],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [39],
#   'resource_count': 1,
#   'rule_id': 18},
#  {'taskno': 'WO106751-20',
#   'task_id': 343380,
#   'priority': 57,
#   'duration': 116,
#   'quantity': 3.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO106751-30',
#   'task_id': 343381,
#   'priority': 57,
#   'duration': 90,
#   'quantity': 3.0,
#   'predecessors': ['WO106751-20'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [44],
#   'resource_count': 1,
#   'rule_id': 55},
#  {'taskno': 'WO106756-10',
#   'task_id': 343387,
#   'priority': 61,
#   'duration': 480,
#   'quantity': 2.0,
#   'predecessors': ['WO106758-20'],
#   'total_resource': 13,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [18],
#   'resource_count': 1,
#   'rule_id': 72},
#  {'taskno': 'WO106756-20',
#   'task_id': 343388,
#   'priority': 61,
#   'duration': 120,
#   'quantity': 2.0,
#   'predecessors': ['WO106756-10'],
#   'total_resource': 8,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [24],
#   'resource_count': 1,
#   'rule_id': 15},
#  {'taskno': 'WO106756-30',
#   'task_id': 343389,
#   'priority': 61,
#   'duration': 472,
#   'quantity': 2.0,
#   'predecessors': ['WO106756-20'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO106758-20',
#   'task_id': 343393,
#   'priority': 61,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [8],
#   'resource_count': 1,
#   'rule_id': 19},
#  {'taskno': 'WO106763-40',
#   'task_id': 343403,
#   'priority': 62,
#   'duration': 40,
#   'quantity': 4.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [39],
#   'resource_count': 1,
#   'rule_id': 18},
#  {'taskno': 'WO106828-20',
#   'task_id': 343504,
#   'priority': 60,
#   'duration': 90,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [8],
#   'resource_count': 1,
#   'rule_id': 19},
#  {'taskno': 'WO106827-10',
#   'task_id': 343681,
#   'priority': 60,
#   'duration': 646,
#   'quantity': 2.0,
#   'predecessors': ['WO106828-20'],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO106827-20',
#   'task_id': 343682,
#   'priority': 60,
#   'duration': 120,
#   'quantity': 2.0,
#   'predecessors': ['WO106827-10'],
#   'total_resource': 8,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [24],
#   'resource_count': 1,
#   'rule_id': 15},
#  {'taskno': 'WO106827-30',
#   'task_id': 343683,
#   'priority': 60,
#   'duration': 866,
#   'quantity': 2.0,
#   'predecessors': ['WO106827-20'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO106881-20',
#   'task_id': 343705,
#   'priority': 59,
#   'duration': 2129,
#   'quantity': 3.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO106881-30',
#   'task_id': 343706,
#   'priority': 59,
#   'duration': 1194,
#   'quantity': 3.0,
#   'predecessors': ['WO106881-20'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [44],
#   'resource_count': 1,
#   'rule_id': 55},
#  {'taskno': 'WO106888-20',
#   'task_id': 344016,
#   'priority': 171,
#   'duration': 30,
#   'quantity': 124.0,
#   'predecessors': [],
#   'total_resource': 8,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [24],
#   'resource_count': 1,
#   'rule_id': 15},
#  {'taskno': 'WO106888-30',
#   'task_id': 344017,
#   'priority': 171,
#   'duration': 4661,
#   'quantity': 124.0,
#   'predecessors': ['WO106888-20'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO107028-10',
#   'task_id': 344337,
#   'priority': 71,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO107029-10',
#   'task_id': 344338,
#   'priority': 76,
#   'duration': 3278,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO107029-20',
#   'task_id': 344339,
#   'priority': 76,
#   'duration': 823,
#   'quantity': 2.0,
#   'predecessors': ['WO107029-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO107030-10',
#   'task_id': 344340,
#   'priority': 75,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO107030-20',
#   'task_id': 344341,
#   'priority': 75,
#   'duration': 690,
#   'quantity': 1.0,
#   'predecessors': ['WO107030-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO107031-10',
#   'task_id': 344342,
#   'priority': 73,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO107031-20',
#   'task_id': 344343,
#   'priority': 73,
#   'duration': 565,
#   'quantity': 1.0,
#   'predecessors': ['WO107031-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO107032-10',
#   'task_id': 344344,
#   'priority': 72,
#   'duration': 1956,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO107032-20',
#   'task_id': 344345,
#   'priority': 72,
#   'duration': 571,
#   'quantity': 1.0,
#   'predecessors': ['WO107032-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO107033-10',
#   'task_id': 344346,
#   'priority': 74,
#   'duration': 271,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [58],
#   'resource_count': 1,
#   'rule_id': 41},
#  {'taskno': 'WO107033-20',
#   'task_id': 344347,
#   'priority': 74,
#   'duration': 898,
#   'quantity': 1.0,
#   'predecessors': ['WO107033-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [53],
#   'resource_count': 1,
#   'rule_id': 52},
#  {'taskno': 'WO107082-10',
#   'task_id': 345035,
#   'priority': 65,
#   'duration': 622,
#   'quantity': 50.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO107121-20',
#   'task_id': 345284,
#   'priority': 46,
#   'duration': 30,
#   'quantity': 34.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO107571-10',
#   'task_id': 347265,
#   'priority': 29,
#   'duration': 22095,
#   'quantity': 1.0,
#   'predecessors': ['WO107644-10', 'WO107645-10', 'WO107643-10', 'WO107646-10'],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO107572-10',
#   'task_id': 347266,
#   'priority': 30,
#   'duration': 22785,
#   'quantity': 1.0,
#   'predecessors': ['WO107630-10',
#    'WO107627-10',
#    'WO107632-10',
#    'WO107635-10',
#    'WO107628-10',
#    'WO107631-10',
#    'WO107633-10',
#    'WO107634-10',
#    'WO107636-10'],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO107627-10',
#   'task_id': 347462,
#   'priority': 30,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO107628-10',
#   'task_id': 347463,
#   'priority': 30,
#   'duration': 55,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO107630-10',
#   'task_id': 347465,
#   'priority': 30,
#   'duration': 115,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO107631-10',
#   'task_id': 347466,
#   'priority': 30,
#   'duration': 47,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO107632-10',
#   'task_id': 347467,
#   'priority': 30,
#   'duration': 920,
#   'quantity': 1.0,
#   'predecessors': ['WO108799-10', 'WO108800-10'],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO107633-10',
#   'task_id': 347468,
#   'priority': 30,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO114308-30',
#    'WO108125-10',
#    'WO114304-30',
#    'WO114306-30',
#    'WO114307-30',
#    'WO114305-30',
#    'WO114303-30',
#    'WO114302-30'],
#   'total_resource': 2,
#   'micro_batch_size': None,
# ...
#   'use_all_resources': False,
#   'resource_group_id': [42],
#   'resource_count': 1,
#   'rule_id': 21},
#  {'taskno': 'WO115097-20',
#   'task_id': 381826,
#   'priority': 124,
#   'duration': 390,
#   'quantity': 39.0,
#   'predecessors': ['WO115097-10'],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [39],
#   'resource_count': 1,
#   'rule_id': 18},
#  {'taskno': 'WO115097-30',
#   'task_id': 381827,
#   'priority': 124,
#   'duration': 390,
#   'quantity': 39.0,
#   'predecessors': ['WO115097-20'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO115098-10',
#   'task_id': 381828,
#   'priority': 279,
#   'duration': 80,
#   'quantity': 4.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [84],
#   'resource_count': 1,
#   'rule_id': 14},
#  {'taskno': 'WO115098-20',
#   'task_id': 381829,
#   'priority': 279,
#   'duration': 172,
#   'quantity': 4.0,
#   'predecessors': ['WO115098-10'],
#   'total_resource': 8,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [24],
#   'resource_count': 1,
#   'rule_id': 15},
#  {'taskno': 'WO115098-30',
#   'task_id': 381830,
#   'priority': 279,
#   'duration': 30,
#   'quantity': 4.0,
#   'predecessors': ['WO115098-20'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO115106-20',
#   'task_id': 381940,
#   'priority': 230,
#   'duration': 403,
#   'quantity': 40.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  {'taskno': 'WO115118-20',
#   'task_id': 382025,
#   'priority': 200,
#   'duration': 6050,
#   'quantity': 300.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [47],
#   'resource_count': 1,
#   'rule_id': 47},
#  {'taskno': 'WO115119-10',
#   'task_id': 382026,
#   'priority': 104,
#   'duration': 1500,
#   'quantity': 300.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [84],
#   'resource_count': 1,
#   'rule_id': 14},
#  {'taskno': 'WO115119-20',
#   'task_id': 382027,
#   'priority': 104,
#   'duration': 6960,
#   'quantity': 300.0,
#   'predecessors': ['WO115119-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [47],
#   'resource_count': 1,
#   'rule_id': 47},
#  {'taskno': 'WO115120-20',
#   'task_id': 382029,
#   'priority': 127,
#   'duration': 6960,
#   'quantity': 300.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [47],
#   'resource_count': 1,
#   'rule_id': 47},
#  {'taskno': 'WO115142-10',
#   'task_id': 382226,
#   'priority': 205,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO115150-10',
#   'task_id': 382239,
#   'priority': 17,
#   'duration': 60,
#   'quantity': 1.0,
#   'predecessors': ['WO115165-20', 'WO115201-20'],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO115151-10',
#   'task_id': 382243,
#   'priority': 24,
#   'duration': 60,
#   'quantity': 1.0,
#   'predecessors': ['WO115176-20', 'WO115175-20', 'WO115203-20'],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO115152-10',
#   'task_id': 382247,
#   'priority': 25,
#   'duration': 60,
#   'quantity': 1.0,
#   'predecessors': ['WO115198-20', 'WO115177-20'],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO115153-10',
#   'task_id': 382248,
#   'priority': 8,
#   'duration': 60,
#   'quantity': 1.0,
#   'predecessors': ['WO115185-20', 'WO115195-20'],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO115154-10',
#   'task_id': 382252,
#   'priority': 16,
#   'duration': 60,
#   'quantity': 1.0,
#   'predecessors': ['WO115174-20', 'WO117159-20'],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO115155-10',
#   'task_id': 382253,
#   'priority': 21,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115851-10', 'WO115194-20'],
#   'total_resource': 7,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [67],
#   'resource_count': 1,
#   'rule_id': 7},
#  {'taskno': 'WO115156-10',
#   'task_id': 382257,
#   'priority': 23,
#   'duration': 60,
#   'quantity': 1.0,
#   'predecessors': ['WO115196-20'],
#   'total_resource': 2,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [38],
#   'resource_count': 1,
#   'rule_id': 24},
#  {'taskno': 'WO115165-10',
#   'task_id': 382275,
#   'priority': 17,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO115165-20',
#   'task_id': 382276,
#   'priority': 17,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115165-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115174-10',
#   'task_id': 382305,
#   'priority': 16,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115265-10'],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO115174-20',
#   'task_id': 382306,
#   'priority': 16,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115174-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115175-10',
#   'task_id': 382307,
#   'priority': 24,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO115175-20',
#   'task_id': 382308,
#   'priority': 24,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115175-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115176-10',
#   'task_id': 382309,
#   'priority': 24,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO115176-20',
#   'task_id': 382310,
#   'priority': 24,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115176-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115177-10',
#   'task_id': 382311,
#   'priority': 25,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO115177-20',
#   'task_id': 382312,
#   'priority': 25,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115177-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115185-10',
#   'task_id': 382340,
#   'priority': 8,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO115185-20',
#   'task_id': 382341,
#   'priority': 8,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115185-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115194-20',
#   'task_id': 382366,
#   'priority': 21,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115195-20',
#   'task_id': 382368,
#   'priority': 8,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115196-20',
#   'task_id': 382370,
#   'priority': 23,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115198-10',
#   'task_id': 382373,
#   'priority': 25,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': [],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO115198-20',
#   'task_id': 382374,
#   'priority': 25,
#   'duration': 30,
#   'quantity': 1.0,
#   'predecessors': ['WO115198-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115201-10',
#   'task_id': 382379,
#   'priority': 17,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': ['WO115267-10', 'WO115266-10'],
#   'total_resource': 9,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [16, 17],
#   'resource_count': 1,
#   'rule_id': 28},
#  {'taskno': 'WO115201-20',
#   'task_id': 382380,
#   'priority': 17,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': ['WO115201-10'],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115203-20',
#   'task_id': 382384,
#   'priority': 24,
#   'duration': 30,
#   'quantity': 2.0,
#   'predecessors': [],
#   'total_resource': 1,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [9],
#   'resource_count': 1,
#   'rule_id': 6},
#  {'taskno': 'WO115215-10',
#   'task_id': 382602,
#   'priority': 20,
#   'duration': 150,
#   'quantity': 10.0,
#   'predecessors': [],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [84],
#   'resource_count': 1,
#   'rule_id': 14},
#  {'taskno': 'WO115215-20',
#   'task_id': 382603,
#   'priority': 20,
#   'duration': 150,
#   'quantity': 10.0,
#   'predecessors': ['WO115215-10'],
#   'total_resource': 4,
#   'micro_batch_size': None,
#   'flow_first_step_id': None,
#   'parent_item_collection_id': None,
#   'predecessor_item_collection_id': None,
#   'use_all_resources': False,
#   'resource_group_id': [69],
#   'resource_count': 1,
#   'rule_id': 17},
#  ...]

# %%
task2job = {}
task2RG = {}
task2duration = {}

task_dict = defaultdict(list)
for task in all_data_files['tasks']:
    task_dict['priority_id'].append(task['priority'])
    task_dict['taskno'].append(task['taskno'])
    task_dict['task_id'].append(task['task_id'])
    task_dict['resource_group_id'].append(task['resource_group_id'])
    task_dict['total_resource'].append(task['total_resource'])
    task_dict['duration'].append(task['duration'])
    task_dict['predecessors'].append(task['predecessors'])
    task_dict['quantity'].append(task['quantity'])

    task2duration[task['taskno']] = task['duration']


    task2job[task['taskno']] = task['priority']

    task2RG[task['taskno']] = task['resource_group_id']

task_frame = pd.DataFrame(task_dict)
task_frame
# Out:
#       priority_id       taskno  task_id resource_group_id  total_resource  \
# 0             323   WO20946-10    79828              [38]               2
# 1             328   WO29559-10   102804              [67]               7
# 2             324   WO30798-20   106244               [3]               1
# 3             339   WO30819-20   106255               [3]               1
# 4             325   WO30820-20   106257               [3]               1
# ...           ...          ...      ...               ...             ...
# 3173          303  WO117905-10   396966              [36]               1
# 3174          303  WO117906-10   396967              [36]               1
# 3175          302  WO117907-10   396968              [36]               1
# 3176          303  WO117908-10   396969              [84]               4
# 3177          291  WO117909-10   396970              [67]               7
#
#       duration   predecessors  quantity
# 0           30             []       1.0
# 1           30             []       1.0
# 2          120             []       1.0
# 3           30             []       1.0
# 4           30             []       2.0
# ...        ...            ...       ...
# 3173        30             []       2.0
# 3174        30             []       2.0
# 3175        30             []       4.0
# 3176        30             []       4.0
# 3177      2366  [WO103020-30]       1.0
#
# [3178 rows x 8 columns]

# %%
task
# Out:
# {'taskno': 'WO117909-10',
#  'task_id': 396970,
#  'priority': 291,
#  'duration': 2366,
#  'quantity': 1.0,
#  'predecessors': ['WO103020-30'],
#  'total_resource': 7,
#  'micro_batch_size': None,
#  'flow_first_step_id': None,
#  'parent_item_collection_id': None,
#  'predecessor_item_collection_id': None,
#  'use_all_resources': False,
#  'resource_group_id': [67],
#  'resource_count': 1,
#  'rule_id': 7}

# %%
task_frame.loc[task_frame['taskno'].str.contains('WO111842-10')]
# Out:
#      priority_id       taskno  task_id resource_group_id  total_resource  \
# 331          237  WO111842-10   368244              [64]               5
#
#      duration predecessors  quantity
# 331        30           []      36.0

# %%
res2RG  = {}
for rg in all_data_files['groups']:
    for rid in rg['resource_id']:
        res2RG[rid] = rg['resource_group_id']

# %%
task_frame.loc[task_frame['predecessors'].str.len()>2]
# Out:
#       priority_id       taskno  task_id resource_group_id  total_resource  \
# 63            173  WO104119-10   333290         [105, 97]               4
# 64            175  WO104120-10   333293         [105, 97]               4
# 114            29  WO107571-10   347265              [67]               7
# 115            30  WO107572-10   347266              [67]               7
# 121            30  WO107633-10   347468              [38]               2
# ...           ...          ...      ...               ...             ...
# 3057          304  WO117823-10   395943          [16, 17]               9
# 3059          301  WO117824-10   395945          [16, 17]               9
# 3061          302  WO117825-10   395947          [16, 17]               9
# 3063           28  WO117826-10   395949            [2, 1]               9
# 3064           28  WO117827-10   395950            [2, 1]               9
#
#       duration                                       predecessors  quantity
# 63        5475            [WO115273-10, WO104121-20, WO104571-10]       1.0
# 64       10106  [WO104436-10, WO104442-10, WO104437-10, WO1044...       1.0
# 114      22095  [WO107644-10, WO107645-10, WO107643-10, WO1076...       1.0
# 115      22785  [WO107630-10, WO107627-10, WO107632-10, WO1076...       1.0
# 121         30  [WO114308-30, WO108125-10, WO114304-30, WO1143...       1.0
# ...        ...                                                ...       ...
# 3057      1400  [WO117870-20, WO117887-10, WO117883-10, WO1178...       1.0
# 3059      1600  [WO117869-20, WO117881-10, WO117868-20, WO1178...       1.0
# 3061      1500  [WO117891-20, WO117880-10, WO117865-20, WO1178...       2.0
# 3063       240            [WO117829-10, WO117828-10, WO117830-10]       1.0
# 3064       240  [WO117831-10, WO117832-10, WO117833-10, WO1178...       1.0
#
# [225 rows x 8 columns]

# %%
solution_dict = defaultdict(list)

count = 0


failed_uids = defaultdict(int)


handled_tasks = defaultdict(bool)

for schedule in tqdm(solution):
    try:
        task2job[schedule['task_uid']]
    except:
        failed_uids['-'.join(schedule['task_uid'].split('-')[:2])]+=1
        count+=1
    
    RGs = list(set([res2RG[int(rid)] for rid in schedule["assigned_resource_ids"]]))

    taskuid = '-'.join(schedule['task_uid'].split('-')[:2])
    if handled_tasks[taskuid]:
        continue
    else:
        handled_tasks[taskuid]=True

    
    for RG in RGs:
        

        solution_dict['JobID'].append(task2job[taskuid])
        solution_dict['TaskID'].append(taskuid)
        solution_dict['ResourceGroup'].append(RG)

        solution_dict['duration'].append(task2duration[taskuid])
        start_,end_ = convert_string_to_list(schedule['resource_intervals'])
        solution_dict['start_time'].append(start_)
        days, hours, minutes = convert_minutes(start_)
        solution_dict['days'].append(days)
        solution_dict['hours'].append(hours)
        solution_dict['minutes'].append(minutes)

solution_frame = pd.DataFrame(solution_dict)

#failed_uids
# Out:
#   0%|          | 0/3704 [00:00<?, ?it/s]
# 100%|██████████| 3704/3704 [00:00<00:00, 19674.71it/s]

# %% [markdown]
# # EDA

# %%
solution_frame['JobID'].unique().shape[0]
# Out:
# 338

# %%
solution_frame['TaskID'].unique().shape[0]
# Out:
# 3178

# %%
d,h,m = convert_minutes(solution_frame['duration'].sum())
print(f"{d} Days {h} Hours and {m} Minutes of Work")

last_job = solution_frame.loc[solution_frame["start_time"]==solution_frame["start_time"].max()]
d,h,m = convert_minutes(last_job['start_time'].values[0]+last_job['duration'].values[0])

print(f"Final Job finished in {d} Days {h} Hours and {m} Minutes")
# Out:
# 1280 Days 18 Hours and 27 Minutes of Work
# Final Job finished in 197.0 Days 21.0 Hours and 50.0 Minutes

# %%
def getRGsets(all_data_files):
    # Create workday lookup
    resource2wd = {resource['resource_id']:resource['availability'] for resource in all_data_files['resource']}

    RG_Sets = defaultdict(list)

    for RG in tqdm(all_data_files['groups']):
        for resource_id in RG['resource_id']:
            try:
                wds = resource2wd[resource_id]
            except:
                print('MISSING:',resource_id)
                continue
            for wd in wds:
                start_,end_ = minutes_since(wd['start_datetime']),minutes_since(wd['end_datetime'])
                if start_ > -1:
                    cur_window = [minute for minute in range(start_,end_+1)]
                    RG_Sets[RG['resource_group_id']].append(cur_window)

    print('AGGREGATING')
    RG_sets_aggregated = {RGid:union_of_lists(windows) for RGid,windows in tqdm(RG_Sets.items())}
    return RG_Sets,RG_sets_aggregated

RG_Sets,RG_sets_aggregated = getRGsets(all_data_files)
# Out:
#   1%|▏         | 1/74 [00:00<00:20,  3.58it/s]
# MISSING: 44
#  15%|█▍        | 11/74 [00:04<00:29,  2.12it/s]
# MISSING: 109
#  16%|█▌        | 12/74 [00:06<00:52,  1.17it/s]
# MISSING: 148
# MISSING: 44
#  26%|██▌       | 19/74 [00:07<00:15,  3.50it/s]
# MISSING: 165
#  51%|█████▏    | 38/74 [00:09<00:03, 10.34it/s]
# MISSING: 236
# MISSING: 236
#  55%|█████▌    | 41/74 [00:11<00:11,  2.88it/s]
# MISSING: 157
#  81%|████████  | 60/74 [00:16<00:03,  3.96it/s]
# MISSING: 157
#  82%|████████▏ | 61/74 [00:16<00:04,  3.00it/s]
# MISSING: 157
#  85%|████████▌ | 63/74 [00:18<00:07,  1.39it/s]
# MISSING: 96
# MISSING: 34
# MISSING: 221
#  86%|████████▋ | 64/74 [00:19<00:06,  1.57it/s]
# MISSING: 82
#  96%|█████████▌| 71/74 [00:21<00:00,  3.92it/s]
# MISSING: 99
# 100%|██████████| 74/74 [00:21<00:00,  3.45it/s]
# AGGREGATING
# 100%|██████████| 71/71 [00:05<00:00, 12.56it/s]

# %%
solution_frame.loc[solution_frame['JobID']==237]
# Out:
#      JobID       TaskID  ResourceGroup  duration  start_time  days  hours  \
# 306    237  WO111842-10             64        30       390.0   0.0    6.0
# 307    237  WO111842-40             65        30       390.0   0.0    6.0
# 308    237  WO111842-50             88      3330       900.0   0.0   15.0
# 309    237  WO111842-50             37      3330       900.0   0.0   15.0
# 417    237  WO112556-10             96     15000    115590.0  80.0    6.0
# ..     ...          ...            ...       ...         ...   ...    ...
# 497    237  WO113074-20             91       188     20850.0  14.0   11.0
# 498    237  WO113082-10            103        55      4896.0   3.0    9.0
# 499    237  WO113082-20             98        30     32550.0  22.0   14.0
# 500    237  WO113085-10             98        30     12375.0   8.0   14.0
# 667    237  WO114366-10            104      2578      6150.0   4.0    6.0
#
#      minutes
# 306     30.0
# 307     30.0
# 308      0.0
# 309      0.0
# 417     30.0
# ..       ...
# 497     30.0
# 498     36.0
# 499     30.0
# 500     15.0
# 667     30.0
#
# [71 rows x 8 columns]

# %%
all_data_files['tasks'][0]
# Out:
# {'taskno': 'WO20946-10',
#  'task_id': 79828,
#  'priority': 323,
#  'duration': 30,
#  'quantity': 1.0,
#  'predecessors': [],
#  'total_resource': 2,
#  'micro_batch_size': None,
#  'flow_first_step_id': None,
#  'parent_item_collection_id': None,
#  'predecessor_item_collection_id': None,
#  'use_all_resources': False,
#  'resource_group_id': [38],
#  'resource_count': 1,
#  'rule_id': 24}

# %%
def get_predecessor_finish(WOids,WO2finish):
    return max([WO2finish[WOid] for WOid in WOids])



def get_overlap_between_RG_and_idle_times(idle_times,task2RG,RG_sets_aggregated):
    print('GETTING IDLE MINUTES')

    idle_minutes = {}

    idle_RGs = defaultdict(list)

    for WOid,idle_time in tqdm(idle_times.items()):
        RGs = task2RG[WOid]
        window = []
        for RG in RGs:
            window+=RG_sets_aggregated[RG]

        
        window = list(set(window))


        idle_range = np.intersect1d(window,idle_time).tolist()

        idle_minutes[WOid] = idle_range

        for RG in RGs:
            idle_RGs[RG]+=idle_range

    idle_RGs = {k:len(set(v)) for k,v in idle_RGs.items()}
    
    return idle_minutes,idle_RGs




def get_task_idle_times(solution,all_data_files,RG_sets_aggregated):

    # Task to Resource Group
    task2RG = {'-'.join(task['taskno'].split('-')) : task['resource_group_id'] for task in all_data_files['tasks']}

    WO2finish = {'-'.join(task['task_uid'].split('-')):task['task_end'] for task in solution}

    task_has_predecessors = {task['taskno']:task['predecessors'] for task in all_data_files['tasks']}

    idle_times  = {}

    # For each task
    print('CREATING DATA STRUCTURE')
    for task in tqdm(solution):
        task_uid = '-'.join(task['task_uid'].split('-')[:2])
        # Check if there are predecessors

        if len(task_has_predecessors[task_uid])>0:
             # If there are precursors find the maximum end time
             # assign the range from (max_precursor_end : start_time) as idle time
            try:
                idle_start = int(get_predecessor_finish(task_has_predecessors[task_uid],WO2finish))
                idle_end = int(task['task_start'])
            except:
                print('failed on predecessors of',task_uid)
                continue

        else:
            # if not assign the range from 0 to start_time as idle_time
            idle_start = 0
            idle_end = int(task['task_start'])


        idle_times[task_uid] = [minute for minute in range(idle_start,idle_end)]


    
    # Get RGs working during idle_times
    idle_minutes,idle_RGs = get_overlap_between_RG_and_idle_times(idle_times,task2RG,RG_sets_aggregated)
    
    # return dictionary {WOid : idle_range} 

    return idle_minutes,idle_RGs

# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-40
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117220-50
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-20
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-30
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-40
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# failed on predecessors of WO117221-50
# 100%|██████████| 3704/3704 [00:05<00:00, 720.11it/s]
# GETTING IDLE MINUTES
# 100%|██████████| 3125/3125 [04:43<00:00, 11.03it/s]

# %%
convert_minutes(len(list(set(idle_minutes['WO109978-10']))))
# Out:
# (1, 6, 12)

# %%
# ANTAL dage ALLE TASKS VENTER PÅ DENNE RESOURCE GROUP 
convert_minutes(idle_RGs[3])
# Out:
# (22, 10, 3)

# %%
# WO DF
# Read In Due dates

# %% [markdown]
# ## WorkOrder DF
# ### Inspect Due Dates

# %%
duedates = pd.read_excel("fctryengine_outputs/EXW_Dates.xlsx",engine='openpyxl')

print(duedates.shape[0])
duedates.head()
# Out:
# 1000
#         taskno exw_delivery_date
# 0  WO109979-10        2023-11-22
# 1  WO109978-10        2023-11-28
# 2  WO109804-10        2023-11-22
# 3  WO109805-10        2023-11-22
# 4  WO109812-10        2023-11-22

# %%
solution[0]
# Out:
# {'task_uid': 'WO100090-40',
#  'assigned_resource_ids': ['114'],
#  'task_start': 1925.0,
#  'task_end': 1955.0,
#  'resource_intervals': 'dict_values([[(1925.0, 1955.0)]])'}

# %%
# Columns
## Priority ID
## WOid
## Minutes idle
## Cur ETA
## DueDate
## Cur delay
## delay without idle-time



# Lookup Definitions
ETA_lookup = {'-'.join(s['task_uid'].split('-')[:2]) : add_minutes_to_date(s['task_end']) for s in solution}
duedate_lookup = {row['taskno']: convert_date_to_datetime(row['exw_delivery_date']) for k,row in duedates.iterrows()}


WorkOrder_dict = defaultdict(list)

for WOid, im in idle_minutes.items():

    WorkOrder_dict['Priority'].append(task2job[WOid])

    WorkOrder_dict['WorkOrder'].append(WOid)

    # Add resource groups 

    WorkOrder_dict['capable_resource_groups'].append('|'.join([str(i) for i in task2RG[WOid]]))

    
    WorkOrder_dict['idle_minutes'].append(len(im))


    # GET ETA FROM SOLUTION
    WorkOrder_dict['ETA'].append(ETA_lookup[WOid])

    # GET DUE DATES FROM duedates
    try:
        dd = duedate_lookup[WOid]
    except:
        dd = None
    WorkOrder_dict['DueDate'].append(dd)



for k,v in WorkOrder_dict.items():
    print(k,len(v))

WorkOrders = pd.DataFrame(WorkOrder_dict)


# Calculate dependant columns

def calculate_timedelta(df, col1, col2):
    df['Delay'] = df[col1] - df[col2]
    return df

WorkOrders = calculate_timedelta(WorkOrders, 'ETA', 'DueDate')
WorkOrders['DelayWithoutIdleTime'] = WorkOrders['Delay'] - pd.to_timedelta(WorkOrders['idle_minutes'], unit='m')
WorkOrders['TimeDifference'] = WorkOrders['Delay'] - WorkOrders['DelayWithoutIdleTime']

WorkOrders.loc[(~WorkOrders['DueDate'].isna())&(WorkOrders['DelayWithoutIdleTime']>pd.Timedelta(0))].sort_values('TimeDifference',ascending=False).head(30)
# Out:
# Priority 3125
# WorkOrder 3125
# capable_resource_groups 3125
# idle_minutes 3125
# ETA 3125
# DueDate 3125
#       Priority    WorkOrder capable_resource_groups  idle_minutes  \
# 689        281  WO114449-10                      58         34406
# 690        281  WO114455-10                      58         33038
# 339        276  WO112156-10                      58         31460
# 341        276  WO112157-10                      58         30618
# 346        275  WO112163-10                      58         29040
# 343        275  WO112159-10                      58         27672
# 433        237  WO112750-10                      58         24700
# 435        237  WO112754-10                      58         24200
# 525        236  WO114078-20                      58         22306
# 552        236  WO114125-10                      58         21464
# 554        236  WO114129-20                      58         20386
# 550        236  WO114121-10                      58         19886
# 167        102  WO110331-10                      58         17992
# 457        237  WO112881-20                      58         17714
# 958        234  WO115494-20                      69         17623
# 459        237  WO112883-20                      58         17541
# 1059       222  WO115894-10                      67         16940
# 1202       192  WO116153-10                      91         16559
# 423        237  WO112685-20                      58         15198
# 880        191  WO115002-10                      30         14520
# 1205       231  WO116155-10                      91         13678
# 73          76  WO107029-10                      58         12626
# 13         138  WO101262-20                      77         10729
# 2192       230  WO117270-10                      67         10669
# 543        236  WO114109-20                      58         10568
